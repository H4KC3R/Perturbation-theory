# %%
import warnings
import sympy as sym
from sympy import Symbol, exp, series, limit, init_printing, sqrt
init_printing()
warnings.filterwarnings('ignore')
eps=Symbol('varepsilon')

# %% [markdown]
# 1) Полагая $f \sim a_1\varepsilon^\alpha + a_2\varepsilon^\beta$ найти $\alpha$, $\beta$ и ненулевые коэффициенты $a_1$, $a_2$:
# $f = (1 + \varepsilon{x})^{1/\varepsilon}$ для 0 < x < $\infty$. Так как x любой примем x = 1

# %%
x = Symbol('x')
f = (1 + eps)**(1/eps)
f
# Out:
# varepsilon________________
#         ╲╱ varepsilon + 1

# %%
limit(f,eps,0,'+')
# Out:
# ℯ

# %%
Nexpand=9 # Порядок разложения
cflst=[eps**i for i in range(0,Nexpand-1)] # Список калибровочных функций
a=[limit(f/cflst[0],eps,0,'+')]  # Первый член разложения
cflst,a
# Out:
# ⎛⎡                         2            3            4            5
# ⎝⎣1, varepsilon, varepsilon , varepsilon , varepsilon , varepsilon , varepsilo
#
#  6            7⎤     ⎞
# n , varepsilon ⎦, [ℯ]⎠

# %%
for i in range(1,Nexpand-1):
    psum=sum([a[j]*cflst[j] for j in range(i)])
    a.append(limit((f-psum)/cflst[i],eps,0,'+'))
sum([a[j]*cflst[j] for j in range(Nexpand-1)])
# Out:
#                     7                      6                   5
#   67223⋅ℯ⋅varepsilon    238043⋅ℯ⋅varepsilon    959⋅ℯ⋅varepsilon    2447⋅ℯ⋅vare
# - ─────────────────── + ──────────────────── - ───────────────── + ───────────
#          165888                580608                 2304                5760
#
#       4                 3                  2
# psilon    7⋅ℯ⋅varepsilon    11⋅ℯ⋅varepsilon    ℯ⋅varepsilon
# ─────── - ─────────────── + ──────────────── - ──────────── + ℯ
#                  16                24               2

# %%
# Проверка с помощью функции series
series(f,eps,0,8,'+').removeO()
# Out:
#                     7                      6                   5
#   67223⋅ℯ⋅varepsilon    238043⋅ℯ⋅varepsilon    959⋅ℯ⋅varepsilon    2447⋅ℯ⋅vare
# - ─────────────────── + ──────────────────── - ───────────────── + ───────────
#          165888                580608                 2304                5760
#
#       4                 3                  2
# psilon    7⋅ℯ⋅varepsilon    11⋅ℯ⋅varepsilon    ℯ⋅varepsilon
# ─────── - ─────────────── + ──────────────── - ──────────── + ℯ
#                  16                24               2

# %% [markdown]
# 2) Найти асимптотические разложения вида $x \sim a_1\varepsilon^\alpha + a_2\varepsilon^\beta + ...$ всех
# корней следующих регулярно возмущенных уравнений
# a) $ x^2 - (3+\varepsilon)x + 1 + \varepsilon = 0$

# %%
from sympy import symbols, Function, diff, collect, solve
Nexpand=9
x=symbols(f'x0:{Nexpand+2}')#Function('x')(eps)
X=Symbol('X')
eq1=X**2 - (3 + eps)*X + 1 + eps # Исходное уравнение
eq1
# Out:
#  2
# X  - X⋅(varepsilon + 3) + varepsilon + 1

# %%
Subsseries=sum(x[i]*eps**i for i in range(Nexpand))# разложение корня в виде ряда по epsilon
# Подстановка ряда в уравнение и группировка по epsilon
Res=series(collect(eq1.subs(X,Subsseries).expand(),eps),eps,0,Nexpand).removeO() 
Res
# Out:
#           8 ⎛                                          2            ⎞
# varepsilon ⋅⎝2⋅x₀⋅x₈ + 2⋅x₁⋅x₇ + 2⋅x₂⋅x₆ + 2⋅x₃⋅x₅ + x₄  - x₇ - 3⋅x₈⎠ + vareps
#
#     7                                                                 6 ⎛
# ilon ⋅(2⋅x₀⋅x₇ + 2⋅x₁⋅x₆ + 2⋅x₂⋅x₅ + 2⋅x₃⋅x₄ - x₆ - 3⋅x₇) + varepsilon ⋅⎝2⋅x₀⋅
#
#                            2            ⎞             5
# x₆ + 2⋅x₁⋅x₅ + 2⋅x₂⋅x₄ + x₃  - x₅ - 3⋅x₆⎠ + varepsilon ⋅(2⋅x₀⋅x₅ + 2⋅x₁⋅x₄ + 2
#
#                                 4 ⎛                      2            ⎞
# ⋅x₂⋅x₃ - x₄ - 3⋅x₅) + varepsilon ⋅⎝2⋅x₀⋅x₄ + 2⋅x₁⋅x₃ + x₂  - x₃ - 3⋅x₄⎠ + vare
#
#       3                                             2 ⎛            2
# psilon ⋅(2⋅x₀⋅x₃ + 2⋅x₁⋅x₂ - x₂ - 3⋅x₃) + varepsilon ⋅⎝2⋅x₀⋅x₂ + x₁  - x₁ - 3⋅
#
#   ⎞                                            2
# x₂⎠ + varepsilon⋅(2⋅x₀⋅x₁ - x₀ - 3⋅x₁ + 1) + x₀  - 3⋅x₀ + 1

# %%
# Находим корни невозмущённого уравнения
roots0=solve(Res.coeff(eps,0))
roots0
# Out:
# ⎡3   √5  √5   3⎤
# ⎢─ - ──, ── + ─⎥
# ⎣2   2   2    2⎦

# %%
# Находим коэффициенты разложения первого корня
root1={x[0]:roots0[0]} 
Sys1=[Res.coeff(eps,i).subs(root1) for i in range(Nexpand)]
for i in range(1,Nexpand):
    root1[x[i]] = solve(Sys1[i].subs(root1), x[i])[0]
Subsseries.subs(root1)
# Out:
#                   8                7                  6                  5
#   11⋅√5⋅varepsilon    √5⋅varepsilon    3⋅√5⋅varepsilon    2⋅√5⋅varepsilon    √
# - ───────────────── + ────────────── + ──────────────── - ──────────────── + ─
#         390625            78125             15625               3125
#
#             3                2
# 5⋅varepsilon    √5⋅varepsilon               ⎛1   √5⎞   √5   3
# ───────────── - ────────────── + varepsilon⋅⎜─ - ──⎟ - ── + ─
#     125               25                    ⎝2   10⎠   2    2

# %%
# Находим коэффициенты разложения второго корня
root2={x[0]:roots0[1]} 
Sys2=[Res.coeff(eps,i).subs(root2) for i in range(Nexpand)]
for i in range(1,Nexpand):
    root2[x[i]] = solve(Sys2[i].subs(root2), x[i])[0]
Subsseries.subs(root2)
# Out:
#                 8                7                  6                  5
# 11⋅√5⋅varepsilon    √5⋅varepsilon    3⋅√5⋅varepsilon    2⋅√5⋅varepsilon    √5⋅
# ───────────────── - ────────────── - ──────────────── + ──────────────── - ───
#       390625            78125             15625               3125
#
#           3                2
# varepsilon    √5⋅varepsilon               ⎛√5   1⎞   √5   3
# ─────────── + ────────────── + varepsilon⋅⎜── + ─⎟ + ── + ─
#   125               25                    ⎝10   2⎠   2    2

# %%
# Разложение точного решения
Sol=solve(eq1,X)
Solseries=[series(sol,eps,0,Nexpand).removeO() for sol in Sol]
Solseries
# Out:
# ⎡                  8                7                  6                  5
# ⎢  11⋅√5⋅varepsilon    √5⋅varepsilon    3⋅√5⋅varepsilon    2⋅√5⋅varepsilon
# ⎢- ───────────────── + ────────────── + ──────────────── - ──────────────── +
# ⎣        390625            78125             15625               3125
#
#              3                2
# √5⋅varepsilon    √5⋅varepsilon               ⎛1   √5⎞   √5   3  11⋅√5⋅varepsil
# ────────────── - ────────────── + varepsilon⋅⎜─ - ──⎟ - ── + ─, ──────────────
#      125               25                    ⎝2   10⎠   2    2        390625
#
#   8                7                  6                  5                3
# on    √5⋅varepsilon    3⋅√5⋅varepsilon    2⋅√5⋅varepsilon    √5⋅varepsilon
# ─── - ────────────── - ──────────────── + ──────────────── - ────────────── +
#           78125             15625               3125              125
#
#              2                               ⎤
# √5⋅varepsilon               ⎛√5   1⎞   √5   3⎥
# ────────────── + varepsilon⋅⎜── + ─⎟ + ── + ─⎥
#       25                    ⎝10   2⎠   2    2⎦

# %% [markdown]
# 3) Найти асимптотические разложения вида $x \sim a_1\varepsilon^\alpha + a_2\varepsilon^\beta + ...$ всех
# корней следующих сингулярно возмущенных уравнений
# a) $ \varepsilon{x^3} - 3x + 1 = 0$

# %% [markdown]
# Если построить многоугольник Ньютона(см. Задание 1)
#
# Первому ребру соответствует многочлен $-3X+1$, тогда начальное приближение корня есть $X_0=\frac{1}{3}$
#
# Второму ребру соответствует многочлен $\varepsilon{X^3}-3X$, тогда начальное приближение корня есть $X_0=\pm\sqrt{\frac{3}{\varepsilon}}$

# %%
Nexpand=9
eq2=eps*X**3-3*X+1 # Исходное уравнение
eq2
# Out:
#  3
# X ⋅varepsilon - 3⋅X + 1

# %%
Subsseries1=sum(x[i]*eps**(i) for i in range(Nexpand))# разложение корня в виде ряда по epsilon
# Подстановка ряда в уравнение и группировка по epsilon
Res1=series(collect(eq2.subs(X,Subsseries1).expand(),eps),eps,0,Nexpand).removeO() 
Subsseries1
# Out:
#           8                7                6                5
# varepsilon ⋅x₈ + varepsilon ⋅x₇ + varepsilon ⋅x₆ + varepsilon ⋅x₅ + varepsilon
#
# 4                3                2
#  ⋅x₄ + varepsilon ⋅x₃ + varepsilon ⋅x₂ + varepsilon⋅x₁ + x₀

# %%
# Находим коэффициенты разложения первого корня
root1={x[0]:1/3} 
Sys1=[Res1.coeff(eps,i).subs(root1) for i in range(Nexpand)]
root1.update(solve(Sys1)[0])
Subsseries1.subs(root1)
# Out:
#                               8                                 7
# 5.10605235545899e-8⋅varepsilon  + 2.47027987473589e-7⋅varepsilon  + 1.22863920
#
#                     6                                 5
# 085548e-6⋅varepsilon  + 6.34194646323933e-6⋅varepsilon  + 3.44974010912469e-5⋅
#
#           4                                  3
# varepsilon  + 0.000203221053701163⋅varepsilon  + 0.00137174211248285⋅varepsilo
#
#  2
# n  + 0.0123456790123457⋅varepsilon + 0.333333333333333

# %%
# Находим второй корень начиная от sqrt (3/epsilon)
Subsseries2= sqrt(3)*eps**(-1/2) + sum(x[i]*eps**(i-1) for i in range(1,Nexpand))# разложение корня в виде ряда по epsilon
# Подстановка ряда в уравнение и группировка по epsilon
Res2=series(collect(eq2.subs(X,Subsseries2).expand(),eps),eps,0,Nexpand).removeO() 
Res2
# Out:
#                0.5   2             8 ⎛    2
# 3⋅√3⋅varepsilon   ⋅x₁  + varepsilon ⋅⎝3⋅x₁ ⋅x₈ + 6⋅x₁⋅x₂⋅x₇ + 6⋅x₁⋅x₃⋅x₆ + 6⋅x
#
#               2                          2       2   ⎞             7 ⎛    2
# ₁⋅x₄⋅x₅ + 3⋅x₂ ⋅x₆ + 6⋅x₂⋅x₃⋅x₅ + 3⋅x₂⋅x₄  + 3⋅x₃ ⋅x₄⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₇
#
#                                     2       2                     3       ⎞
#  + 6⋅x₁⋅x₂⋅x₆ + 6⋅x₁⋅x₃⋅x₅ + 3⋅x₁⋅x₄  + 3⋅x₂ ⋅x₅ + 6⋅x₂⋅x₃⋅x₄ + x₃  - 3⋅x₈⎠ +
#
#           6 ⎛    2                                    2             2       ⎞
# varepsilon ⋅⎝3⋅x₁ ⋅x₆ + 6⋅x₁⋅x₂⋅x₅ + 6⋅x₁⋅x₃⋅x₄ + 3⋅x₂ ⋅x₄ + 3⋅x₂⋅x₃  - 3⋅x₇⎠
#
#             5 ⎛    2                          2       2          ⎞
# + varepsilon ⋅⎝3⋅x₁ ⋅x₅ + 6⋅x₁⋅x₂⋅x₄ + 3⋅x₁⋅x₃  + 3⋅x₂ ⋅x₃ - 3⋅x₆⎠ + varepsilo
#
#  4 ⎛    2                     3       ⎞             3 ⎛    2             2
# n ⋅⎝3⋅x₁ ⋅x₄ + 6⋅x₁⋅x₂⋅x₃ + x₂  - 3⋅x₅⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₃ + 3⋅x₁⋅x₂  - 3
#
#    ⎞             2 ⎛    2          ⎞              ⎛  3       ⎞
# ⋅x₄⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₂ - 3⋅x₃⎠ + varepsilon⋅⎝x₁  + 6⋅x₂⎠ + 6⋅√3⋅varepsil
#
#   1.5                     2.0                2.5 ⎛                    2⎞
# on   ⋅x₁⋅x₂ + 9⋅varepsilon   ⋅x₃ + varepsilon   ⋅⎝6⋅√3⋅x₁⋅x₃ + 3⋅√3⋅x₂ ⎠ + 9⋅v
#
#          3.0                3.5                                         4.0
# arepsilon   ⋅x₄ + varepsilon   ⋅(6⋅√3⋅x₁⋅x₄ + 6⋅√3⋅x₂⋅x₃) + 9⋅varepsilon   ⋅x₅
#
#              4.5 ⎛                                 2⎞               5.0
#  + varepsilon   ⋅⎝6⋅√3⋅x₁⋅x₅ + 6⋅√3⋅x₂⋅x₄ + 3⋅√3⋅x₃ ⎠ + 9⋅varepsilon   ⋅x₆ + v
#
#          5.5                                                      6.0
# arepsilon   ⋅(6⋅√3⋅x₁⋅x₆ + 6⋅√3⋅x₂⋅x₅ + 6⋅√3⋅x₃⋅x₄) + 9⋅varepsilon   ⋅x₇ + var
#
#        6.5 ⎛                                              2⎞               7.0
# epsilon   ⋅⎝6⋅√3⋅x₁⋅x₇ + 6⋅√3⋅x₂⋅x₆ + 6⋅√3⋅x₃⋅x₅ + 3⋅√3⋅x₄ ⎠ + 9⋅varepsilon
#
#                 7.5
# ⋅x₈ + varepsilon   ⋅(6⋅√3⋅x₁⋅x₈ + 6⋅√3⋅x₂⋅x₇ + 6⋅√3⋅x₃⋅x₆ + 6⋅√3⋅x₄⋅x₅) + vare
#
#       8.5 ⎛                                              2⎞
# psilon   ⋅⎝6⋅√3⋅x₂⋅x₈ + 6⋅√3⋅x₃⋅x₇ + 6⋅√3⋅x₄⋅x₆ + 3⋅√3⋅x₅ ⎠ + 6⋅x₁ + 1

# %%
# Находим коэффициенты разложения второго корня
root2=dict() 
Sys2=[Res2.coeff(eps,i) for i in range(Nexpand-1)]
root2.update(solve(Sys2)[0])
Subsseries2.subs(root2)
# Out:
#                                     7                 6               5
#              -0.5    2141⋅varepsilon    197⋅varepsilon    5⋅varepsilon    55⋅v
# √3⋅varepsilon     - ───────────────── - ─────────────── + ───────────── + ────
#                     10968475320188928    50779978334208    117546246144     65
#
#          4               3             2
# arepsilon    5⋅varepsilon    varepsilon    varepsilon   1
# ────────── + ───────────── + ─────────── + ────────── - ─
# 30347008        10077696        46656         1296      6

# %%
# Находим третий корень начиная от - sqrt (3/epsilon)
Subsseries3=-sqrt(3)*eps**(-1/2) + sum(x[i]*eps**(i-1) for i in range(1,Nexpand))# разложение корня в виде ряда по epsilon
# Подстановка ряда в уравнение и группировка по epsilon
Res3=series(collect(eq2.subs(X,Subsseries3).expand(),eps),eps,0,Nexpand).removeO() 
Res3
# Out:
#                  0.5   2             8 ⎛    2
# - 3⋅√3⋅varepsilon   ⋅x₁  + varepsilon ⋅⎝3⋅x₁ ⋅x₈ + 6⋅x₁⋅x₂⋅x₇ + 6⋅x₁⋅x₃⋅x₆ + 6
#
#                 2                          2       2   ⎞             7 ⎛    2
# ⋅x₁⋅x₄⋅x₅ + 3⋅x₂ ⋅x₆ + 6⋅x₂⋅x₃⋅x₅ + 3⋅x₂⋅x₄  + 3⋅x₃ ⋅x₄⎠ + varepsilon ⋅⎝3⋅x₁ ⋅
#
#                                       2       2                     3       ⎞
# x₇ + 6⋅x₁⋅x₂⋅x₆ + 6⋅x₁⋅x₃⋅x₅ + 3⋅x₁⋅x₄  + 3⋅x₂ ⋅x₅ + 6⋅x₂⋅x₃⋅x₄ + x₃  - 3⋅x₈⎠
#
#             6 ⎛    2                                    2             2
# + varepsilon ⋅⎝3⋅x₁ ⋅x₆ + 6⋅x₁⋅x₂⋅x₅ + 6⋅x₁⋅x₃⋅x₄ + 3⋅x₂ ⋅x₄ + 3⋅x₂⋅x₃  - 3⋅x₇
#
# ⎞             5 ⎛    2                          2       2          ⎞
# ⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₅ + 6⋅x₁⋅x₂⋅x₄ + 3⋅x₁⋅x₃  + 3⋅x₂ ⋅x₃ - 3⋅x₆⎠ + varepsi
#
#    4 ⎛    2                     3       ⎞             3 ⎛    2             2
# lon ⋅⎝3⋅x₁ ⋅x₄ + 6⋅x₁⋅x₂⋅x₃ + x₂  - 3⋅x₅⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₃ + 3⋅x₁⋅x₂  -
#
#      ⎞             2 ⎛    2          ⎞              ⎛  3       ⎞
#  3⋅x₄⎠ + varepsilon ⋅⎝3⋅x₁ ⋅x₂ - 3⋅x₃⎠ + varepsilon⋅⎝x₁  + 6⋅x₂⎠ - 6⋅√3⋅vareps
#
#     1.5                     2.0                2.5 ⎛                     2⎞
# ilon   ⋅x₁⋅x₂ + 9⋅varepsilon   ⋅x₃ + varepsilon   ⋅⎝-6⋅√3⋅x₁⋅x₃ - 3⋅√3⋅x₂ ⎠ +
#
#             3.0                3.5                                          4.
# 9⋅varepsilon   ⋅x₄ + varepsilon   ⋅(-6⋅√3⋅x₁⋅x₄ - 6⋅√3⋅x₂⋅x₃) + 9⋅varepsilon
#
# 0                4.5 ⎛                                  2⎞               5.0
#  ⋅x₅ + varepsilon   ⋅⎝-6⋅√3⋅x₁⋅x₅ - 6⋅√3⋅x₂⋅x₄ - 3⋅√3⋅x₃ ⎠ + 9⋅varepsilon   ⋅x
#
#               5.5                                                       6.0
# ₆ + varepsilon   ⋅(-6⋅√3⋅x₁⋅x₆ - 6⋅√3⋅x₂⋅x₅ - 6⋅√3⋅x₃⋅x₄) + 9⋅varepsilon   ⋅x₇
#
#              6.5 ⎛                                               2⎞
#  + varepsilon   ⋅⎝-6⋅√3⋅x₁⋅x₇ - 6⋅√3⋅x₂⋅x₆ - 6⋅√3⋅x₃⋅x₅ - 3⋅√3⋅x₄ ⎠ + 9⋅vareps
#
#     7.0                7.5
# ilon   ⋅x₈ + varepsilon   ⋅(-6⋅√3⋅x₁⋅x₈ - 6⋅√3⋅x₂⋅x₇ - 6⋅√3⋅x₃⋅x₆ - 6⋅√3⋅x₄⋅x₅
#
#               8.5 ⎛                                               2⎞
# ) + varepsilon   ⋅⎝-6⋅√3⋅x₂⋅x₈ - 6⋅√3⋅x₃⋅x₇ - 6⋅√3⋅x₄⋅x₆ - 3⋅√3⋅x₅ ⎠ + 6⋅x₁ +
#
#
# 1

# %%
# Находим коэффициенты разложения третьего корня
root3=dict() 
Sys3=[Res3.coeff(eps,i) for i in range(Nexpand-1)]
root3.update(solve(Sys3)[0])
Subsseries3.subs(root3)
# Out:
#                                       7                 6               5
#                -0.5    2141⋅varepsilon    197⋅varepsilon    5⋅varepsilon    55
# - √3⋅varepsilon     - ───────────────── - ─────────────── + ───────────── + ──
#                       10968475320188928    50779978334208    117546246144
#
#            4               3             2
# ⋅varepsilon    5⋅varepsilon    varepsilon    varepsilon   1
# ──────────── + ───────────── + ─────────── + ────────── - ─
# 6530347008        10077696        46656         1296      6
